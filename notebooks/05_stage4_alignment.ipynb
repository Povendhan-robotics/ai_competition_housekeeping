# %%
# %cd /content/ai-competition-baselines

# Infer on TEST for submission
# !python -m src.stage4_alignment.infer \
  --config configs/stage4_alignment.yaml \
  --data_root "$DATA_ROOT" \
  --test_dir images/test \
  --out submissions/stage4.csv

# !head -n 5 submissions/stage4.csv

# %%
# %cd /content/ai-competition-baselines

# Infer on VAL for evaluation
# !python -m src.stage4_alignment.infer \
  --config configs/stage4_alignment.yaml \
  --data_root "$DATA_ROOT" \
  --test_dir images/val \
  --out submissions/stage4_val_pred.csv

# !python -m src.stage4_alignment.eval \
  --gt "$DATA_ROOT/labels/stage4_val.csv" \
  --pred submissions/stage4_val_pred.csv
