# %%
# %cd /content/ai-competition-baselines
# First generate predictions on val by pointing test_dir to images/val (for quick check)
# !python -m src.stage1_binary.infer \
  --config configs/stage1_binary.yaml \
  --data_root "$DATA_ROOT" \
  --ckpt runs/stage1_binary/best_stage1.pt \
  --test_dir images/val \
  --out submissions/stage1_val_pred.csv

# !python -m src.stage1_binary.eval \
  --gt "$DATA_ROOT/labels/stage1_val.csv" \
  --pred submissions/stage1_val_pred.csv
